# %% [markdown]
# In this project, I'm interested in looking at the Algebra2/Trigonometry Regents Exam mean score in Benjamin Cardozo High School and want to compare it with Bayside High School.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
df.head(30)
# Out:
#    School DBN                     School Name School Level  \
# 0      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3      01M140          P.S. 140 Nathan Straus          K-8
# 4      01M140          P.S. 140 Nathan Straus          K-8
# 5      01M140          P.S. 140 Nathan Straus          K-8
# 6      01M140          P.S. 140 Nathan Straus          K-8
# 7      01M140          P.S. 140 Nathan Straus          K-8
# 8      01M184            P.S. 184m Shuang Wen          K-8
# 9      01M184            P.S. 184m Shuang Wen          K-8
# 10     01M184            P.S. 184m Shuang Wen          K-8
# 11     01M184            P.S. 184m Shuang Wen          K-8
# 12     01M188      P.S. 188 The Island School          K-8
# 13     01M188      P.S. 188 The Island School          K-8
# 14     01M188      P.S. 188 The Island School          K-8
# ...

# %%
df.tail(30)
# Out:
#        School DBN                         School Name     School Level  \
# 212301     84X704         KIPP Academy Charter School  K-12 all grades
# 212302     84X705  Family Life Academy Charter School              K-8
# 212303     84X705  Family Life Academy Charter School              K-8
# 212304     84X705  Family Life Academy Charter School              K-8
# 212305     84X705  Family Life Academy Charter School              K-8
# 212306     84X705  Family Life Academy Charter School              K-8
# 212307     84X705  Family Life Academy Charter School              K-8
# 212308     84X706       Harriet Tubman Charter School              K-8
# 212309     84X706       Harriet Tubman Charter School              K-8
# 212310     84X706       Harriet Tubman Charter School              K-8
# 212311     84X706       Harriet Tubman Charter School              K-8
# 212312     84X706       Harriet Tubman Charter School              K-8
# ...

# %%
df.shape
# Out:
# (212331, 15)

# %%
df. isnull().sum()
# Out:
# School DBN                     0.0
# School Name                    0.0
# School Level                   0.0
# Regents Exam                   0.0
# Year                           0.0
# Total Tested                   0.0
# Mean Score                     0.0
# Number Scoring Below 65        0.0
# Percent Scoring Below 65       0.0
# Number Scoring 65 or Above     0.0
# Percent Scoring 65 or Above    0.0
# Number Scoring 80 or Above     0.0
# Percent Scoring 80 or Above    0.0
# Number Scoring CR              0.0
# Percent Scoring CR             0.0
# dtype: float64

# %%
df.dropna()
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
df[df['School Name'] == 'Benjamin N. Cardozo High School']
# Out:
#        School DBN                      School Name School Level  \
# 14511      26Q415  Benjamin N. Cardozo High School  High school
# 14512      26Q415  Benjamin N. Cardozo High School  High school
# 14513      26Q415  Benjamin N. Cardozo High School  High school
# 14514      26Q415  Benjamin N. Cardozo High School  High school
# 14515      26Q415  Benjamin N. Cardozo High School  High school
# ...           ...                              ...          ...
# 194043     26Q415  Benjamin N. Cardozo High School  High school
# 194044     26Q415  Benjamin N. Cardozo High School  High school
# 194045     26Q415  Benjamin N. Cardozo High School  High school
# 194046     26Q415  Benjamin N. Cardozo High School  High school
# 194047     26Q415  Benjamin N. Cardozo High School  High school
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 14511         Algebra2/Trigonometry  2015           644         67
# ...

# %%
from matplotlib import pyplot as plt
_df_8['Total Tested'].plot(kind='hist', bins=20, title='Total Tested')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df[df['School Name'] == 'Bayside High School']
# Out:
#        School DBN          School Name School Level  \
# 14623      26Q495  Bayside High School  High school
# 14624      26Q495  Bayside High School  High school
# 14625      26Q495  Bayside High School  High school
# 14626      26Q495  Bayside High School  High school
# 14627      26Q495  Bayside High School  High school
# ...           ...                  ...          ...
# 194590     26Q495  Bayside High School  High school
# 194591     26Q495  Bayside High School  High school
# 194592     26Q495  Bayside High School  High school
# 194593     26Q495  Bayside High School  High school
# 194594     26Q495  Bayside High School  High school
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 14623         Algebra2/Trigonometry  2015           652       62.8
# 14624         Algebra2/Trigonometry  2016           802       61.5
# 14625           Common Core Algebra  2015          1364       64.5
# ...

# %%
df.groupby(['School Name'])['Regents Exam','Mean Score'].count()
# Out:
# <ipython-input-48-5fdedc4a54b7>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['School Name'])['Regents Exam','Mean Score'].count()
#                                                     Regents Exam  Mean Score
# School Name
# 47 The American Sign Language and English Secondar           356         356
# A. Philip Randolph Campus High School                        459         459
# ACORN Community High School                                  364         364
# Abraham Lincoln High School                                  480         480
# Abraham Lincoln Yabc                                         248         248
# ...                                                          ...         ...
# Young Women's Leadership School                              378         378
# Young Women's Leadership School of Brooklyn                  337         337
# ...

# %%
from matplotlib import pyplot as plt
_df_14['Regents Exam'].plot(kind='hist', bins=20, title='Regents Exam')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df = df[(df['School Name'] == 'Benjamin N. Cardozo High School')&(df['Mean Score'] == 'Algebra2/Trigonometry')]

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: [School DBN, School Name, School Level, Regents Exam, Year, Total Tested, Mean Score, Number Scoring Below 65, Percent Scoring Below 65, Number Scoring 65 or Above, Percent Scoring 65 or Above, Number Scoring 80 or Above, Percent Scoring 80 or Above, Number Scoring CR, Percent Scoring CR]
# Index: []

# %% [markdown]
# I would like to extract the Algebra2/Trigonometry Regents Exam mean score for Benjamin and Cardozo High School from the dataset, but no result returned.
