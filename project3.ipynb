# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install pandas
import pandas as pd

# %%
df = pd.read_csv('NYPD_Arrest_Data__Year_to_Date__20231228.csv')

# %%
df.head(50)
# Out:
#    ARREST_DATE                         PD_DESC                     OFNS_DESC  \
# 0   01/01/2023        ASSAULT 2,1,UNCLASSIFIED                FELONY ASSAULT
# 1   02/03/2023     CONTROLLED SUBSTANCE,SALE 3               DANGEROUS DRUGS
# 2   02/15/2023               STRANGULATION 1ST                FELONY ASSAULT
# 3   01/04/2023               STRANGULATION 1ST                FELONY ASSAULT
# 4   02/13/2023        ASSAULT 2,1,UNCLASSIFIED                FELONY ASSAULT
# 5   01/17/2023               STRANGULATION 1ST                FELONY ASSAULT
# 6   01/23/2023               STRANGULATION 1ST                FELONY ASSAULT
# 7   03/04/2023                          RAPE 3                          RAPE
# 8   01/25/2023  FORGERY,ETC.,UNCLASSIFIED-FELO                       FORGERY
# 9   03/17/2023   BURGLARY,UNCLASSIFIED,UNKNOWN                      BURGLARY
# 10  01/30/2023                     ARSON 2,3,4                         ARSON
# ...

# %%
df.shape
# Out:
# (170095, 19)

# %%
df.columns
# Out:
# Index(['ARREST_KEY', 'ARREST_DATE', 'PD_CD', 'PD_DESC', 'KY_CD', 'OFNS_DESC',
#        'LAW_CODE', 'LAW_CAT_CD', 'ARREST_BORO', 'ARREST_PRECINCT',
#        'JURISDICTION_CODE', 'AGE_GROUP', 'PERP_SEX', 'PERP_RACE', 'X_COORD_CD',
#        'Y_COORD_CD', 'Latitude', 'Longitude', 'New Georeferenced Column'],
#       dtype='object')

# %%
# drop columns that I'm not interested in this project
df.drop(['ARREST_KEY', 'PD_CD', 'KY_CD',
       'LAW_CODE', 'LAW_CAT_CD',
       'JURISDICTION_CODE', 'X_COORD_CD',
       ], axis=1, inplace=True)

# %%
print(df)
# Out:
#        ARREST_DATE                         PD_DESC  \
# 0       01/01/2023        ASSAULT 2,1,UNCLASSIFIED
# 1       02/03/2023     CONTROLLED SUBSTANCE,SALE 3
# 2       02/15/2023               STRANGULATION 1ST
# 3       01/04/2023               STRANGULATION 1ST
# 4       02/13/2023        ASSAULT 2,1,UNCLASSIFIED
# ...            ...                             ...
# 170090  07/07/2023  ROBBERY,OPEN AREA UNCLASSIFIED
# 170091  08/18/2023      CHILD, ENDANGERING WELFARE
# 170092  09/13/2023  TRAFFIC,UNCLASSIFIED INFRACTIO
# 170093  06/15/2023    STOLEN PROPERTY 3,POSSESSION
# 170094  07/28/2023  FORGERY,ETC.,UNCLASSIFIED-FELO
#
#                             OFNS_DESC ARREST_BORO  ARREST_PRECINCT AGE_GROUP  \
# 0                      FELONY ASSAULT           K               77     45-64
# 1                     DANGEROUS DRUGS           K               73     25-44
# 2                      FELONY ASSAULT           K               62     25-44
# ...

# %%
#filter Queens boro from the dataset
df_queens = df.loc[df['ARREST_BORO'] == 'Q']
print(df_queens)
# Out:
#        ARREST_DATE                         PD_DESC  \
# 5       01/17/2023               STRANGULATION 1ST
# 11      02/02/2023                       ASSAULT 3
# 18      02/18/2023                       ASSAULT 3
# 22      05/03/2023                          RAPE 3
# 29      06/14/2023               STRANGULATION 1ST
# ...            ...                             ...
# 170070  08/30/2023              FORGERY,ETC.-MISD.
# 170080  08/17/2023         AGGRAVATED HARASSMENT 2
# 170081  06/13/2023  FORGERY,ETC.,UNCLASSIFIED-FELO
# 170084  05/25/2023  PUBLIC ADMINISTRATION,UNCLASSI
# 170086  07/25/2023  TRAFFIC,UNCLASSIFIED INFRACTIO
#
#                             OFNS_DESC ARREST_BORO  ARREST_PRECINCT AGE_GROUP  \
# 5                      FELONY ASSAULT           Q              113     45-64
# 11       ASSAULT 3 & RELATED OFFENSES           Q              108       <18
# 18       ASSAULT 3 & RELATED OFFENSES           Q              105     18-24
# ...

# %%
 #under df_queens, compare the arrest rate in different age groups

df_queens[['ARREST_PRECINCT', 'AGE_GROUP']]
# Out:
#         ARREST_PRECINCT AGE_GROUP
# 5                   113     45-64
# 11                  108       <18
# 18                  105     18-24
# 22                  100     18-24
# 29                  101     45-64
# ...                 ...       ...
# 170070              105     25-44
# 170080              109     45-64
# 170081              113     18-24
# 170084              109     25-44
# 170086              109     25-44
#
# [36246 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_55['ARREST_PRECINCT'].plot(kind='hist', bins=20, title='ARREST_PRECINCT')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_56.groupby('AGE_GROUP').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# compare number of arrests in diffrent sexes in Queens boro
df_queens[['ARREST_PRECINCT', 'PERP_SEX']]
# Out:
#         ARREST_PRECINCT PERP_SEX
# 5                   113        F
# 11                  108        M
# 18                  105        M
# 22                  100        M
# 29                  101        U
# ...                 ...      ...
# 170070              105        F
# 170080              109        M
# 170081              113        M
# 170084              109        M
# 170086              109        M
#
# [36246 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_44['ARREST_PRECINCT'].plot(kind='hist', bins=20, title='ARREST_PRECINCT')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_45.groupby('PERP_SEX').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# *We can conclude from the graphs above that, the 25-44 age group dominates the arrest rate in Queens borough.In addition, Male has leading arrest rate in Queens when comparing to other sexes. *
